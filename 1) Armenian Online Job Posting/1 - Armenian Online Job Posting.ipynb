# %% [markdown]
# **Author**: Marcello Victorino<br>
# **Date**: 04/16 -
# <hr>

# %% [markdown]
# # Data Wrangling: Armenian Online Job Posting
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# # Introduction
#
# The [dataset](https://www.kaggle.com/udacity/armenian-online-job-postings) consists of 19,000 job postings between 2004 - 2015, with 24 Columns.
#
# **Variables Description:**
# 1. **jobpost**: The original job post.<br>
# + **date**: The date it was posted in the group.<br>
# + **Title**: Job title.<br>
# + **Company**: Employer name. <br>
# + **AnnouncementCode**: Announcement code, which is some internal code and is usually missing.<br>
# + **Term**: Full-Time, Part-time, etc.<br>
# + **Eligibility**: Eligibility of the candidates.<br>
# + **Audience**: Who can apply? <br>
# + **StartDate**: Start date of work.<br>
# + **Duration**: Duration of the employment.<br>
# + **Location**: Employment location.<br>
# + **JobDescription**: Job Description.<br>
# + **JobRequirment**: Job requirements.<br>
# + **RequiredQual**: Required qualifications.<br>
# + **Salary**: Job salary.<br>
# + **ApplicationP**: Application procedure.<br>
# + **OpeningDate**: Opening date of the job announcement.<br>
# + **Deadline**: Deadline for the job announcement. <br>
# + **Notes**: Additional notes.<br>
# + **AboutC**: About the company.<br>
# + **Attach**: Attachments.<br>
# + **Year**: Year of the announcement (derived from the field date). <br>
# + **Month**: Month of the announcement (derived from the field date). <br>
# + **IT**: TRUE if the job is an IT job. This variable is created by a simple search of IT job titles within the "Title" column.<br>
#
# This Project Goal is to Wrangle this dataset, assessing and cleaning it before we can perform EDA or modeling.
#
# Let's import the necessary libraries and read the data into a dataframe:

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# <a id='wrangling'></a>
# # Data Wrangling

# %% [markdown]
# ## Gather

# %%
df = pd.read_csv('online-job-postings.csv')
df.head(5)
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# 2        Caucasus Environmental NGO Network (CENN)              NaN  NaN
# 3                                     Manoff Group              NaN  NaN
# 4                           Yerevan Brandy Company              NaN  NaN
#
#   Eligibility Audience StartDate                               Duration  ...  \
# 0         NaN      NaN       NaN                                    NaN  ...
# 1         NaN      NaN       NaN                               3 months  ...
# 2         NaN      NaN       NaN  Renewable annual contract\r\nPOSITION  ...
# 3         NaN      NaN       NaN                                    NaN  ...
# 4         NaN      NaN       NaN                                    NaN  ...
#
#   Salary                                       ApplicationP OpeningDate  \
# 0    NaN  To apply for this position, please submit a\r\...         NaN
# 1    NaN  Please submit a cover letter and resume to:\r\...         NaN
# 2    NaN  Please send resume or CV toursula.kazarian@......         NaN
# 3    NaN  Please send cover letter and resume to Amy\r\n...         NaN
# 4    NaN  Successful candidates should submit\r\n- CV; \...         NaN
#
#                                         Deadline Notes  \
# 0                                26 January 2004   NaN
# 1                                12 January 2004   NaN
# 2  20 January 2004\r\nSTART DATE:  February 2004   NaN
# 3      23 January 2004\r\nSTART DATE:  Immediate   NaN
# 4                         20 January 2004, 18:00   NaN
#
#                                               AboutC Attach  Year Month     IT
# 0                                                NaN    NaN  2004     1  False
# 1  The International Research & Exchanges Board (...    NaN  2004     1  False
# 2  The Caucasus Environmental NGO Network is a\r\...    NaN  2004     1  False
# 3                                                NaN    NaN  2004     1  False
# 4                                                NaN    NaN  2004     1   True
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Assess

# %%
# Missing Values
df.isna().any()
# Out:
# jobpost             False
# date                False
# Title                True
# Company              True
# AnnouncementCode     True
# Term                 True
# Eligibility          True
# Audience             True
# StartDate            True
# Duration             True
# Location             True
# JobDescription       True
# JobRequirment        True
# RequiredQual         True
# Salary               True
# ApplicationP         True
# OpeningDate          True
# Deadline             True
# Notes                True
# AboutC               True
# Attach               True
# Year                False
# Month               False
# IT                  False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19001 entries, 0 to 19000
# Data columns (total 24 columns):
# jobpost             19001 non-null object
# date                19001 non-null object
# Title               18973 non-null object
# Company             18994 non-null object
# AnnouncementCode    1208 non-null object
# Term                7676 non-null object
# Eligibility         4930 non-null object
# Audience            640 non-null object
# StartDate           9675 non-null object
# Duration            10798 non-null object
# Location            18969 non-null object
# JobDescription      15109 non-null object
# JobRequirment       16479 non-null object
# RequiredQual        18517 non-null object
# Salary              9622 non-null object
# ApplicationP        18941 non-null object
# OpeningDate         18295 non-null object
# Deadline            18936 non-null object
# Notes               2211 non-null object
# AboutC              12470 non-null object
# Attach              1559 non-null object
# Year                19001 non-null int64
# Month               19001 non-null int64
# IT                  19001 non-null bool
# dtypes: bool(1), int64(2), object(21)
# memory usage: 3.4+ MB

# %%
# Investigate groups relevance of Variables
var = df.Term
try:
    items = var.value_counts().items()
    [print(f'{k[:50]} | {v}') for k,v in items]
except:
    print(var.value_counts())
# Out:
# Full time | 5348
# Full-time | 1078
# Part time | 136
# Full Time | 104
# Long term | 102
# Part-time or Full-time | 92
# Part-time | 68
# Permanent | 51
# Long-term | 22
# Full time salaried - 40 hours per week | 15
# Full-Time | 14
# Long Term | 13
# ASAP | 13
# Short term | 9
# Up to 5 years | 9
# Fixed term | 8
# Full time or part time | 8
# Part time/ Full time | 8
# Full time/ Part time | 7
# Part-time/ Full-time | 7
# Part time or full time | 6
# Long term, with 3 months probation period | 6
# Full term | 6
# Full-tim | 6
# Long term with 3 months probation period | 6
# Full time (8 working hours per day). | 6
# Service Contract | 5
# Full time, flex time | 5
# Part-time or full-time | 5
# Full time (40 hrs/week) | 5
# Short-term | 5
# Full time, 40 hours/week | 5
# Morning, night and afternoon shifts | 4
# Contract based | 4
# 50 hrs per week | 4
# Contract | 4
# Full-time; 40 hours/week | 4
# According to current curricula | 4
# Full time (6 days, 9:00-18:00, 18:00-24:00) | 4
# Night shift | 4
# Part-time (Full-time preferable) | 4
# Full time/ Part time, flexible hours | 4
# Full time, 6 days per week. | 3
# Long term with 3 months probation period. | 3
# Full- time | 3
# Hourly based | 3
# Full time, night shift | 3
# Part Time | 3
# Temporary | 3
# Contractual | 3
# Full time / Part time | 3
# Full-time/ Part-time | 3
# Up to 30 days over 5 months period | 3
# Full time or Part time | 3
# Contract-based | 3
# Full time/ part time | 3
# Long term with three months probation period | 3
# Full-time, from Monday to Friday 10:00 - 18:00, Sa | 3
# Flexible | 3
# Service contract | 3
# Flexible hours | 3
# Fulltime | 3
# Freelance | 3
# Full time, Night shift | 3
# Day/ night shifts | 2
# Full Time / Part Time | 2
# Long-term with 3 months probation period | 2
# Long term with probation period | 2
# The lessons are held once a week for an hour. | 2
# Full time, Monday - Friday | 2
# Full time, 40 hours per week, Monday - Friday | 2
# Free schedule | 2
# Fixed-term | 2
# Full time, working hours flexible | 2
# Part-time (or Full-time) | 2
# Full time (08:30 - 18:00) | 2
# Termless | 2
# Full time, 5 days per week | 2
# Part time (25 hours a week). | 2
# Special Short Term Ungraded Contract | 2
# Part time: 4 hours/day | 2
# Day shift | 2
# 50 working days (LOEs) during the period of March- | 2
# Project based | 2
# Indefinite term contract with 3 months probation p | 2
# Full time (Part time is also acceptable) | 2
# Based on the Employment Contract. | 2
# Term appointment | 2
# Full time. | 2
# Long term with 3 month probation period. | 2
# Part time, by service contract | 2
# Full time / Shift based | 2
# Contract with Temporary and Short Term Jobs | 2
# Full-time (9:00 a.m. - 6:00 p.m.) | 2
# Full time (from Monday to Friday, 9:00 - 17:30). | 2
# Fixed work hours | 2
# Morning, afternoon and night shifts | 2
# Position implies 12-hours schedule also with night | 2
# Full - time | 2
# Full time, from Monday to Friday, 9:00 - 17:30 | 2
# Full-time engagement | 2
# Full-term | 2
# 5-6 days/ week, 7 hours/ day. Working hours: 9:00  | 2
# Part time/ 20 hours per week. | 2
# Full time (with night shifts) | 2
# Full time, 6 days per week | 2
# Full-time/ part-time | 2
# Night-time | 2
# On weekends | 2
# Fixed-term ExB | 1
# Full-timeOPEN TO/ ELIGIBILITY
# CRITERIA:All qualif | 1
# Two day schedule- 08.00-17.00; 17.00-02.00, one da | 1
# 5-6 days/ week, 7 hours/ day. Working hours: 9:00- | 1
# Fixed working hours. | 1
# full time | 1
# 24-hour shift | 1
# Night Shift | 1
# Full-time employment. | 1
# 1 academic year | 1
# Full time, from Monday to Friday 10:00 - 18:00, Sa | 1
# Free lance, flexible hours, can be easily combined | 1
# 6 months. Renewable. | 1
# Short-term appointment | 1
# Part-time, 1 hour per week | 1
# Full-time on premises | 1
# Permanent with 3 month probation period. | 1
# Approximately 6 months | 1
# Full-time or Part-time | 1
# Full-time/ Part time | 1
# 6 months (with one month probation period). Renewa | 1
# Full-time 40-48 hours per week; Monday  Saturday | 1
# The position implies a 12-hour schedule, night shi | 1
# Full time, with 1 month probation period. | 1
# Flexible (full time, part time, work from home) | 1
# Work hours: 9.00-19.00 (day off - Sunday) | 1
# Full time/ Part time with flexible hours | 1
# Long Term with 3 months probation. | 1
# This is a part time (75%) position that requires 3 | 1
# Full time (irregular working schedule). | 1
# Full-time with 3 months of probation period | 1
# Night-time / Full time | 1
# 4-5 hours per day, mostly from 16:00 to 20:00. | 1
# 6-12 days a month | 1
# September 2008 | 1
# Full time (6 days a week; work hours: 9:00-18:00) | 1
# Part time evolving to full time | 1
# Fixed Term | 1
# Full -Time | 1
# Full time /35 hours per week/. Conditioned working | 1
# Part time, preferably in the morning | 1
# Full time or part time, flexible hours | 1
# Permanent, with 3 months probationary period. | 1
# Full time (or Part time). | 1
# 3 months | 1
# Full  and/or part time | 1
# 01 December  2009 - 30 June 2010 | 1
# Full tme | 1
# Full time, 9:00 AM  5:30 PM, Monday - Friday, 40 h | 1
# Part time - 50%, 2.5 working days per week | 1
# Unlimited | 1
# Local contract, fixed-term | 1
# Part-Time | 1
# Part-time/ as required | 1
# 24 hours a working day with 2 days of rest. | 1
# FT/PT (rotating shift) | 1
# Full -time | 1
# 20h/week or full time | 1
# 25 h/week | 1
# Full time contract | 1
# 2 years | 1
# Full time (hours negotiable before 08 January 2015 | 1
# Short term, service contract | 1
# Local Contracted | 1
# Part time (50%) position | 1
# Based on service contract. | 1
# Part time/ free working hours | 1
# Full time (54 hours / week) and Part time (39 hour | 1
# Permanent, with 3 months probation period | 1
# Long term (with 3 months probation period). | 1
# Full-time with a probation period. | 1
# Full time or part time with flexible working hours | 1
# Full time (45 hours/  week). | 1
# Full time or part-time | 1
# Part-time, working hours 10.00-14.15 | 1
# As per contract | 1
# Short Term Contract, up to 150 days | 1
# Part-time (with expansion soon to full-time) | 1
# Long term/ permanent | 1
# Full time (with one week probation period) | 1
# Part-time/ 2 posts | 1
# Free work schedule. | 1
# One year contract with possible extension | 1
# Full time, 8 hours daily from Monday to Friday and | 1
# 8 hours a day (9:30-18:30), 5 day work week | 1
# Flexible work schedule | 1
# As soon as possible | 1
# Full time or part-time (for students) | 1
# Contractual position | 1
# Free working schedule | 1
# Short-Term (about 50-60 days to be completed withi | 1
# The position is for a three-year fixed term appoin | 1
# Irregular hourly/ daily basis | 1
# Full time, with night and day shift. | 1
# Full time: 08:45-18:00, Sundays 10:00-15:00. | 1
# Full time; 35 hours per week. Conditioned working  | 1
# 3/4 FTE | 1
# 1 - year standard contract | 1
# Part-time (20 hours per week - 5 times 4 hours) | 1
# Part time schedule | 1
# Full time (from 09:00  18:00; the position require | 1
# Part-time - 3 hours a day, one hour presence in th | 1
# One year with possible extension for one additiona | 1
# On contractual basis | 1
# Full time is desirable (from 09:00 to 18:00 o'cloc | 1
# December 1, 2012  May 31, 2013 | 1
# Full time, Monday  Friday with occasional work in  | 1
# Part-time position - 50% | 1
# Fixed-Term Appointment (NOB) | 1
# Service Contract (GS-5) | 1
# Fourth quarter of 2012 | 1
# 20 Days | 1
# Full time. The work schedule will include evening  | 1
# Permanent employement opportunity with 6 months pr | 1
# Part time, 14:00 - 18:00 | 1
# Full-time (40 hours/ week) | 1
# Full time (6 days a week, from 10:00 to 22:00, may | 1
# 08:30 - 18:00 | 1
# 40 hours per week. | 1
# Contract Job | 1
# Full time (40 hours/week) | 1
# Fixed-term appointment | 1
# Termless after 3 month probation period. | 1
# Full time, Mondays - Fridays, from 9:00 - 18:00 | 1
# Full time, regular working hours | 1
# Full time (40 hours/week), salaried. | 1
# Short-Term | 1
# Full time / free schedule | 1
# Part time ( from 2-6 pm) | 1
# Full or part time | 1
# Full time or freelance | 1
# PT/50% (20 hours per week) with flexible schedule | 1
# Part time, 32 hours per week, generally Monday  Fr | 1
# Full time (15 June 2014  25 June 2014, 13 August 2 | 1
# On call bases | 1
# Renewable Term  Appointment | 1
# Both part time and full time are considered. | 1
# 22 working hours weekly/ 88 working hours monthly | 1
# Six months with 2 month probation period (with pos | 1
# About 2 to 3 days per month | 1
# Once a week for 1,5 hours | 1
# Full time, 6 day work week | 1
# One year with possible extension for a second year | 1
# Long term with 3 months probation | 1
# Indefinite with 3 months of probation period. | 1
# Full time (on shift) | 1
# Full Time/Half Time | 1
# Part-time (09:00-13:00) | 1
# Indefinite fulltime contract | 1
# Contract /Part-time (20 hrs a week) | 1
# Temporary, six months with possible extension. | 1
# 4 - 5 hours daily, Monday - Friday | 1
# Full time (9 am - 6 pm) | 1
# Short-term and Long-term | 1
# Part-time position with a potential of becoming fu | 1
# Part time position for Dilijan project, which may  | 1
# Possible promotion to part time or full time perma | 1
# Part time for the nearest months, full-time - ther | 1
# Full time, additional employment negotiable | 1
# Full time, part time employment is possible for st | 1
# Working hours: 09:00  19:00 from Monday to Friday. | 1
# Long term with three months probation | 1
# Yerevan, Armenia (with periodic travel to field of | 1
# Part-time, with possible shift to full-time in the | 1
# Morning, evening and night shifts | 1
# Part-time (as required) | 1
# Full Time/ Long Term | 1
# 8-12 hours a day | 1
# Full time, every other day | 1
# Full-time (6 days, 9:00-18:00, 18:00-24:00) | 1
# Service provision agreement | 1
# Full time (40-48 hrs per week; Monday  Saturday wo | 1
# FTA (ICS7/G7) | 1
# 09:00 - 18:00 (Sunday-day off) | 1
# Full-time/ on a concrete assignment basis. | 1
# Part time (20 hours per week) with flexible schedu | 1
# Working hours: 10:00-19:00 | 1
# Part time, 25 hours per week. Conditioned working  | 1
# 25 days | 1
# Working hours: 17:00-01:00 | 1
# Full time (preferably) | 1
# Full time (with flexible schedule) | 1
# Once in a week | 1
# 5 day training | 1
# Full time, with 2 months probation | 1
# Full time, 40 hours per week, 09:00  18:00, Lunch  | 1
# Full-time, 40 hours per week, Monday - Friday | 1
# Part- tme | 1
# Full-time, 8 hours daily from Monday to Friday and | 1
# Full time. Part-time employment is also possible s | 1
# Full time (discussible) | 1
# Working hours: 8.30 a.m.-6.00 p.m., 5 days a week. | 1
# Long term, subject to one month probation period | 1
# 9-12 hours a day | 1
# Full time (260 days per year) | 1
# Full time and part time | 1
# Full time (from 08:30 to 18:00). | 1
# Full time/Part time | 1
# Immediate, with a probation period of 3 months | 1
# Long term with 1 month probation period. | 1
# Part-time (preferably morning hours) | 1
# Immediately | 1
# Full-time and part-time | 1
# Full-time contract | 1
# We offer temporary to permanent positions. | 1
# Service Agreement | 1
# 5-6 days/week, 8 hours/day. Working hours: 9:30-18 | 1
# Full time (Monday-Friday: 9:00-18:00, Saturday: 9: | 1
# Full time (40 hours weekly, five-day week). | 1
# Full time: 5 days/ 40 hours a week | 1
# 50% (2.5 working days). | 1
# Full time, 40 hours per week, Monday  Friday. | 1
# 3 days per week | 1
# Full-time/part-time | 1
# 4-5 hours per day mostly from 16:00 to 20:00 | 1
# Long term with three months probation period. | 1
# Fixed | 1
# Full time, 5.5 days per week | 1
# Freelance or steady work | 1
# Full time (15
# June 2014  25 June 2014, 13 August  | 1
# Up to 100 consultant days within period of Novembe | 1
# Full-time, 40hrs/week, 3 shifts, flexible | 1
# Grade 4, Step 1, UN Salary Scale for General Servi | 1
# Piece-work | 1
# Full-time after 3-month probation period | 1
# Part-time, flexible | 1
# Part time, ideal for someone who has 2 hours free  | 1
# Part-time work | 1
# Full  time | 1
# Part time and full time | 1
# Part time (5-6 hours a day). | 1
# Part-time, from 09:00 to 14:00. | 1
# Full time/ Part-time | 1
# Part-time / night shifts | 1
# Permanent employment opportunity (with 3 months in | 1
# Full time (or 30 hours per week). | 1
# Full-time, from Monday to Friday, hours 09.00  18. | 1
# Full-time, from Monday to Friday 10:00-18:00 | 1
# 20 Workdays | 1
# Morning and afternoon shifts | 1
# Full time (9:00-18:00) | 1
# Definite term with further  possibility of  incorp | 1
# 5 days (40 hours) per week. | 1
# Monday- Friday, 18:00 - 24:00 (01:00) | 1
# 1 full-time; 5 part-time; 1 temporary | 1
# Part  time | 1
# Non-Specified | 1
# 5 days/ week, 7 hours/ day. Working hours - 9:00-2 | 1
# Full time (10 am - 7 pm) | 1
# The incumbent will be working on weekends. | 1
# Permanent with three months probation. | 1
# 12 months - renewable | 1
# Night shift, working hours (18:00 - 09:00), also n | 1
# Part-time (non fixed hours) | 1
# According to profile and experience | 1
# Part time/ Full Time | 1
# 6 months | 1
# Full time (9.00 a.m.-5.00 p.m.) | 1
# 40 hours a week | 1
# 24 hours work and 2 days rest. | 1
# Full time, permanent | 1
# Part time, 4 hours/ weekly | 1
# Full time, from 9:00 to 18:00 (lunch break: from 1 | 1
# On a freelance basis | 1
# Full time from 10-19, lunch 1 hour, 5 days a week, | 1
# Full time (can be night shift) | 1
# Full time (11:00 - 20:00, 6 days a week) | 1
# Part -time, flexible schedule | 1
# Open Ended | 1
# Initially three months, with possible extension up | 1
# Either a full time employee or a long term freelan | 1
# Full/Part time | 1
# Full time (9.30 - 18.30) | 1
# Full-time; part-time employment is possible for st | 1
# Full Time (9.00 a.m.-5.00 p.m.) | 1
# Part-time (4 hours per day) | 1
# Full time (40 hours/ week) | 1
# Part-time as determined by the project budget (pot | 1
# Working hours: 45 hrs per week | 1
# Full time/ flex time | 1
# Fixed-term/G2 | 1
# Part time (3 hours a day) | 1
# Night shift work | 1
# Full time,10:00-20:00 | 1
# Full time It will be based in Armenia and will dir | 1
# Working hours: 9:00 - 18:00 (strictly) | 1
# Flexible work hours | 1
# Night and afternoon shifts | 1
# Long-term. Depending on demonstrated achievements | 1
# Part-time position | 1
# Fix term | 1
# long term, 40 hours/ 5 days | 1
# Full-time availability | 1
# long-term | 1
# Full time (6 days a week, from 10:00 to 22:00, may | 1
# Part time/full time | 1
# Full time (shifted) | 1
# Fixed term, on replacement capacity | 1
# Full time (from 10:00 to 19:00, from Monday to Sat | 1
# Full time (45 hours/ week). | 1
# Freelance/ Part time/ Full time | 1
# Full time (8-hour a day, 42 hours weekly, occasion | 1

# %% [markdown]
# ## Assess
#
# + **Irrelevant Information:**  either brings no informative value or has few relevant groups
#     - jobpost: original data scraped into columns
#     - Eligibility
#     - Audience
#     - Notes
#     - AboutC (company)
#     - Attach
#     - AnnouncementCode
#     - JobDescription
#     - JobRequirment
#     - Salary: competitive!?
#     - ApplicationP (process)
#
#
# + **Potentially Informative:**
#     - RequiredQual: requires scraping for key-words identification and count
#     - date: periods of time with spike in job posting?
#     - Title: hottest professions
#     - Company: Biggest hirers
#     - Term: correlation between contract kind (Full vs Part time) and other variables (job, requirement, salary)
#     - StartDate: planned hiring or necessity?
#     - Duration: correlation between duration and other variables
#     - Location: hottest places per sector
#     - OpeningDate - Deadline: application window
#
#
# + **Redundant Values:**
#     - Term: Full time, Full-time ...
#     - Start Date: ASAP , Immediately, As soon as Possible ...
#     - Duration: Long term, Long-term ...
#     - Location: Yerevan, Armenia + description
#     - Opening Date: formatting (blank space)
#     - Deadline: Rolling, Rolling Groups, value + description
#     - Title: requires aggregation (Software Developer, Java developer, Web developer...)
#
#
# + **Data Type:**
#     - date: object -> datetime
#     - OpeningDate: object -> datetime
#     - Deadline: object -> datetime
#
# + **Columns name:**
#     - standardize string format (lower, _ instead of space or Camel Case)
#
#
# + **Missing values**: Redo after pre cleaning NaN (in 19 columns)

# %% [markdown]
# ## Cleaning Plan

# %% [markdown]
# ### Issue 1
# #### Define
# Remove irrelevant variables from dataframe: ['jobpost', 'Eligibility', 'Audience', 'Notes', 'AboutC', 'Attach', 'AnnouncementCode', 'JobDescription', 'JobRequirment', 'Salary', 'ApplicationP']

# %% [markdown]
# #### Code

# %%
drop_variables = ['jobpost', 'Eligibility', 'Audience', 'Notes', 'AboutC',
            'Attach', 'AnnouncementCode', 'JobDescription', 'JobRequirment',
            'Salary', 'ApplicationP']

df.drop(columns=drop_variables, inplace=True)

# %% [markdown]
# #### Test

# %%
assert drop_variables not in df.columns.tolist()

# %% [markdown]
# ### Issue 2
# #### Define
# Term: standardize values in representative groups | 'Full-time', 'Part-time', 'Full/Part-time', 'Contract', and 'Other'

# %% [markdown]
# #### Code

# %%
# Verification of outcome before actually replacing the dataframe
def check_replacement(column, pattern):
    print(column.str.contains(pattern).sum())
    return column.replace(regex=pattern, value='Test', inplace=False).value_counts()

# %%
# Substitute line-breaks with underscore so regex can 'search' properly - entire dataframe
df.replace('\n','_', inplace=True, regex=True)

# %%
# Regex patterns to capture the entire value for each category to be aggregated
full_or_part_regex = '(?i)(?=full.*part).*|(?=part.*full).*|both.*' # 194 cases, both full and part
full_time_regex = '(?i)(full|long|permanent)(?!/).*' # 6,963 cases
part_time_regex = '(?i)(?<!/)part.*' # 251
contract_regex = '(?i).*(contract|freelance).*' # 49 cases, contract or freelance

# %%
# check_replacement(df.Term, full_or_part_regex)

# %%
# Actually saving value replacement
df.Term.replace(regex={full_or_part_regex: 'Full/Part-time',
                      full_time_regex: 'Full-time',
                       part_time_regex: 'Part-time',
                      contract_regex: 'Contract'}, inplace=True)

term_categories_list =  ['Full/Part-time', 'Full-time','Part-time', 'Contract']

# Rename everything else as 'Other'
df.Term.where(np.isin(df.Term, term_categories_list) ,'Other', inplace=True)

# %% [markdown]
# #### Test

# %%
# Visually check if category aggregation worked
df.Term.value_counts()
# Out:
# Other             11544
# Full-time          6963
# Part-time           251
# Full/Part-time      194
# Contract             49
# Name: Term, dtype: int64

# %%
term_new_categories = ['Full/Part-time', 'Full-time','Part-time','Contract', 'Other']
term_categories_df = df.Term.value_counts().keys().tolist()
assert all([(category in term_new_categories) for category in term_categories_df])

# %% [markdown]
# ### Issue 3
# #### Define
# StartDate: standardize values in representative groups | 'ASAP' and 'Other'

# %% [markdown]
# #### Code

# %%
# asap_regex = '(?i).*(asap|immediat*|soon|upon hiring).*'
# check_replacement(df.StartDate, asap_regex)

# %%
asap_regex = '(?i).*(asap|immediat*|soon|upon hiring).*'

# Actually saving value replacement
df.StartDate.replace(regex={asap_regex: 'ASAP'}, inplace=True)

# Rename everything else as 'Other'
df.StartDate.where(df.StartDate == 'ASAP', 'Other', inplace=True)

# %%
df.StartDate.value_counts()
# Out:
# Other    12148
# ASAP      6853
# Name: StartDate, dtype: int64

# %% [markdown]
# #### Test

# %%
StartDate_categories_new = ['ASAP', 'Other']
StartDate_categories_df = df.StartDate.value_counts().keys().tolist()

assert all([category in StartDate_categories_new for category in StartDate_categories_df])

# %% [markdown]
# ### Issue 4
# #### Define
# Duration: standardize values in representative groups | 'Permanent', 'Up to 1 Year', '2-5 years', 'Other

# %%
# mid_regex = '(?i).*([2-5].*year*).*'
# check_replacement(df.Duration, mid_regex)

# %%
permanent_regex = '(?i).*(long|perma*|open|indef*|term.*less|unlimited).*'
short_regex = '(?i).*(short|month*|1.*year|one.*year|week*|day*|temp*).*'
mid_regex = '(?i).*([2-5].*year*|(two|three|four|five) years).*' # 270 cases

# Actually saving value replacement
df.Duration.replace(regex={permanent_regex: 'Permanent',
                           short_regex: 'Up to 1 Year',
                          mid_regex: '2-5 years'}, inplace=True)

# %%
# Rename everything else as 'Other'
duration_categories_list = ['Permanent', 'Up to 1 Year', '2-5 years']
df.Duration.where(np.isin(df.Duration, duration_categories_list), 'Other', inplace=True)

# %%
df.Duration.value_counts()
# Out:
# Other           8556
# Permanent       8381
# Up to 1 Year    1848
# 2-5 years        216
# Name: Duration, dtype: int64

# %% [markdown]
# #### Test

# %%
Duration_categories_new = ['Permanent', 'Up to 1 Year', '2-5 years', 'Other']
Duration_categories_df = df.Duration.value_counts().keys().tolist()

assert all([category in Duration_categories_new for category in Duration_categories_df])

# %% [markdown]
# ### Issue 5
# #### Define
# Location: standardize values in representative groups | Main cities

# %%
# description_regex = '(?i).*(description).*'
# check_replacement(df.Location, description_regex)

# %%
yerevan_regex = '(?i).*(yerevan).*' # Capital city of Armenia
description_regex = '(?i).*(description|location|position|detail*).*' # Bad entries with full description

# Actually saving value replacement
df.Location.replace(regex={yerevan_regex: 'Yerevan, Armenia',
                          description_regex: 'Other'}, inplace=True)

# %%
# Replace all that do not have "city, country" pattern as "Other"
general_cities_regex = '(?i).*([a-z]*,.*[a-z]).*'
general_city_pattern = df.Location.str.contains(general_cities_regex, na=False)

df.Location.where(general_city_pattern, 'Other', inplace=True)
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# #### Test

# %%
# Visually assessing categories
df.Location.value_counts()
# Out:
# Yerevan, Armenia                                                                                                            17581
# Other                                                                                                                         152
# Gyumri, Armenia                                                                                                               102
# Abovyan, Armenia                                                                                                               95
# Tbilisi, Georgia                                                                                                               74
# Vanadzor, Armenia                                                                                                              72
# Kapan, Armenia                                                                                                                 68
# Dilijan, Armenia                                                                                                               30
# Tsaghkadzor, Armenia                                                                                                           28
# Stepanakert, NKR                                                                                                               23
# Echmiadzin, Armenia                                                                                                            20
# Stepanakert, Nagorno Karabakh                                                                                                  19
# Ashtarak, Armenia                                                                                                              15
# Artashat, Armenia                                                                                                              15
# Etchmiadzin, Armenia                                                                                                           14
# Armavir, Armenia                                                                                                               13
# Sevan, Armenia                                                                                                                 13
# Goris, Armenia                                                                                                                 12
# Stepanavan, Armenia                                                                                                            12
# Moscow, Russia                                                                                                                 11
# Vardenis, Armenia                                                                                                              11
# Lori region, Armenia                                                                                                           11
# Charentsavan, Armenia                                                                                                          10
# Gavar, Armenia                                                                                                                 10
# Hrazdan, Armenia                                                                                                               10
# Ararat, Armenia                                                                                                                 9
# Ijevan, Armenia                                                                                                                 8
# Sisian, Armenia                                                                                                                 8
# v. Vardadzor, Martakert region, Republic of Nagorno Karabakh                                                                    8
# Alaverdi, Armenia                                                                                                               8
#                                                                                                                             ...
# Village Mayakovsiy, Kotayk region, (near Abovyan), Armenia                                                                      1
# Halidzor-Tatev villages of Syunik region, Armenia                                                                               1
# Mumbai, India                                                                                                                   1
# Armenian Field Office. The project will be implemented in all\r_three Caucasus countriesArmenia, Azerbaijan and Georgia.        1
# Gegharquniq Marz, Armenia                                                                                                       1
# Chambarak, Armenia                                                                                                              1
# Hrazdan, Kotayk Marz, Armenia                                                                                                   1
# Gyumri, Shirak Region, Armenia                                                                                                  1
# Pekin, China                                                                                                                    1
# Tsapatagh, Gegharkounik region, Armenia                                                                                         1
# Charentsavan (Kotayk marz), Armenia                                                                                             1
# 49, Tigran Metsi Ave., 6th floor                                                                                                1
# Northern Regions, Armenia                                                                                                       1
# Tshambarak, Armenia                                                                                                             1
# Home-based, Armenia                                                                                                             1
# Arevadasht, Armenia                                                                                                             1
# Rome, Italy                                                                                                                     1
# Abkhasia, Georgia                                                                                                               1
# Stepanavan, Lori Region, Armenia                                                                                                1
# Aragatsotn Marz,  Armenia                                                                                                       1
# Regions, Armenia                                                                                                                1
# Vayots Dzor Marz, Armenia                                                                                                       1
# IREX Armenia, CMSPA                                                                                                             1
# Stepanakert,  Nagorno-Karabakh                                                                                                  1
# Gyumri, Shirak marz                                                                                                             1
# Sharjah, United Arab Emirates                                                                                                   1
# Dubai, United Arab Emirates                                                                                                     1
# Gavar, Gegharkunik marz,  Armenia                                                                                               1
# v. Mayakovskiy, Kotayk reg.,  Armenia                                                                                           1
# Sisian Region, Armenia                                                                                                          1
# Name: Location, Length: 341, dtype: int64

# %% [markdown]
# ### Issue 6
# #### Define
# OpeningDate:
# + fix formatting | extra blank space and special character
# + Then convert datatype to Datetime

# %% [markdown]
# #### Code

# %%
# Fixing double spacing and special character
df.OpeningDate.replace(regex={'\r_': ' ', '  ':' '}, inplace=True)

# %%
# Transforming all to Datetime. Errors='coerce' handles Missing values 
df.OpeningDate = pd.to_datetime(df.OpeningDate, errors='coerce')

# %% [markdown]
# #### Test

# %%
assert df.OpeningDate.dtype == np.dtype('datetime64[ns]')

# %% [markdown]
# ### Issue 7
# #### Define
# Deadline:
# + Remove irrelevant text to clean Date Format
# + Aggregate meaningless text values (i.e. "open" or "rolling")
# + Then convert datatype to Datetime, setting non date as NaT

# %%
# not_date_regex = '(?i)(open|roll*).*'
# check_replacement(df.Deadline, not_date_regex)

# %%
description_regex = '(?i)(\r_|close|cob|cet).*' # general text mixed with date to be removed
not_date_regex = '(?i)(open|roll*|for).*'

# Actually saving value replacement
df.Deadline.replace(regex={description_regex: '',
                          not_date_regex: 'Other'}, inplace=True)

# %%
# Transforming all to Datetime. Errors='coerce' handles Missing values 
df.Deadline = pd.to_datetime(df.Deadline, errors='coerce')

# %% [markdown]
# #### Test

# %%
assert df.OpeningDate.dtype == np.dtype('datetime64[ns]')

# %% [markdown]
# ### Issue 8
# #### Define
# Title: aggregate into new categories | ..............
# + Remove any educational offerings (not job related)

# %%
# regex = '(?i).*(developer|software|QA|programmer).*'
# check_replacement(df.Title, regex)

# %%
finance_regex = '(?i).*(account*|finan*|audit*|loan|credit|contract).*'
not_job_regex = '(?i).*(course*).*'
developer_regex = '(?i).*(developer|software|QA|programmer).*'
administrative_regex = '(?i).*(office|project|administr*|manag*|leader|superv*).*'
marketing_regex = '(?i).*(market*|sale*|brand|merchand*|commercial|PR|advert*).*'
designer_regex = '(?i).*(design*|user experience).*'
receptionist_regex = '(?i).*(reception*|assistant|secret*).*'
legal_regex = '(?i).*(legal|law*).*'
engineer_regex = '(?i).*(engin*).*'
analyst_regex = '(?i).*(analy*|business consultant).*'
medical_regex = '(?i).*(medic*|pharmac*|nurs*).*'
it_regex = '(?i).*(it|technical support).*'
high_management_regex = '(?i).*(director|chief).*'
support_regex = '(?i).*(hr|human|procurement|customer|call center).*'

# Actually saving value replacement
df.Title.replace(regex={finance_regex: 'Finance',not_job_regex: 'remove',
                        developer_regex: 'Developer',administrative_regex: 'Administrative',
                       marketing_regex: 'Marketing/Sales',designer_regex: 'Designer',
                       receptionist_regex: 'Receptionist/Assistant', legal_regex: 'Legal',
                       engineer_regex: 'Misc. Engineer', analyst_regex: 'Analyst',
                       medical_regex: 'Healthcare', it_regex: 'IT',
                       high_management_regex: 'Higher Management',
                       support_regex: 'Supporting Services'}, inplace=True)

# %%
# Remove entries offering Course
df.drop(index=df.query('Title == "remove"').index, inplace=True)

# %%
# Rename everything else as 'Other'
title_categories_list = ['Finance', 'Developer', 'Marketing/Sales', 'Receptionist/Assistant',
                        'Misc. Engineer', 'Healthcare', 'Higher Management', 'Supporting Services']
df.Title.where(np.isin(df.Title, title_categories_list), 'Other', inplace=True)

# %%
df.Title.value_counts()
# Out:
# Other                     9337
# Developer                 2956
# Finance                   2376
# Marketing/Sales           2279
# Misc. Engineer             778
# Receptionist/Assistant     565
# Higher Management          253
# Supporting Services        176
# Healthcare                 104
# Name: Title, dtype: int64

# %% [markdown]
# #### Test

# %%
Title_categories_new = ['Finance', 'Developer', 'Marketing/Sales', 'Receptionist/Assistant',
                        'Misc. Engineer', 'Healthcare', 'Higher Management', 'Supporting Services',
                       'Other']
Title_categories_df = df.Title.value_counts().keys().tolist()
assert all([(category in Title_categories_new) for category in Title_categories_df])

# %% [markdown]
# ### Issue 9
# #### Define
# Data type: set date from object to Datetime

# %%
df2 = df.copy()

# %%
df2.date = pd.to_datetime(df2.date, errors='coerce')
df2.date.count() - len(df)
df[df2.date.isnull()]
# Out:
#                   date            Title  \
# 311     Jun 1 10:13 PM            Other
# 313     Jun 3 11:31 AM            Other
# 314     Jun 3 11:36 AM            Other
# 315     Jun 3 11:37 AM            Other
# 316     Jun 3 10:23 PM            Other
# 317     Jun 4 11:37 PM            Other
# 318      Jun 7 4:59 AM        Developer
# 319     Jun 7 10:57 PM            Other
# 320     Jun 7 10:38 PM            Other
# 321     Jun 7 11:53 PM        Developer
# 322     Jun 8 12:16 AM            Other
# 323      Jun 8 2:17 AM        Developer
# 324     Jun 8 11:53 PM            Other
# 325     Jun 9 11:08 PM          Finance
# 326     Jun 9 11:07 PM            Other
# 327    Jun 10 12:14 AM          Finance
# 328    Jun 10 10:46 PM          Finance
# 329    Jun 10 10:47 PM  Marketing/Sales
# 330    Jun 10 10:46 PM  Marketing/Sales
# 331     Jun 12 4:49 AM            Other
# 332     Jun 13 2:02 AM   Misc. Engineer
# 333     Jun 13 2:10 AM            Other
# 334    Jun 13 11:09 PM            Other
# 335    Jun 13 11:05 PM            Other
# 336     Jun 14 4:50 AM            Other
# 337     Jun 14 4:53 AM            Other
# 338     Jun 14 4:52 AM            Other
# 339     Jun 14 4:49 AM            Other
# 340     Jun 14 4:50 AM  Marketing/Sales
# 341     Jun 14 9:28 PM  Marketing/Sales
# ...                ...              ...
# 17777           May 26            Other
# 17778           May 25        Developer
# 17779           May 26          Finance
# 17780           May 26            Other
# 17781           May 26            Other
# 17782           May 27          Finance
# 17783           May 27  Marketing/Sales
# 17784           May 27            Other
# 17785           May 27            Other
# 17786           May 27            Other
# 17787           May 27          Finance
# 17788           May 27            Other
# 17789           May 28            Other
# 17790           May 28            Other
# 17791           May 29          Finance
# 17792           May 29            Other
# 17793           May 29            Other
# 17794           May 29            Other
# 318    - Languages: C/C++, JAVA, C-Sharp, Visual Basi...         NaT
# 319    Higher education, let the job be either hobby\...         NaT
# 320    - Demonstrated experience creating presentatio...  2001-07-01
# 321    - Excellent proficiency in ASP, C#, ASP.NET, J...         NaT
# 322    - University Degree in Information Technologie...         NaT
# 323    - 3+ years experience with information technol...         NaT
# 324    - Bachelors or higher degree in architecture, ...         NaT
# 325    - Appropriate education in the field of Financ...         NaT
# 326    -\tUniversity degree\r_-\tAt least three years...         NaT
# 327    - Higher education in Economics/Finance (advan...  2004-06-10
# 328    - Economic Background is preferred \r_- Min 1 ...  2004-06-10
# 329    - Higher education in Economics/Finance (advan...         NaT
# 330    - Higher education \r_- English, Russian and A...  2004-06-10
# 331    - Complete higher education, \r_- Excellent kn...  2004-06-12
# 332    The candidate must be an EXPERT in the field\r...         NaT
# 333                                                  NaN  2004-06-12
# 334    - 20-35 years old\r_- Minimum 1 year driving e...         NaT
# 335              French language knowledge is desirable.         NaT
# 336              French language knowledge is desirable.         NaT
# 337              French language knowledge is desirable.         NaT
# 338              French language knowledge is desirable.         NaT
# 339              French language knowledge is desirable.         NaT
# 340              French language knowledge is desirable.         NaT
# 341    - 10 years experience in higher education, inc...         NaT
# ...                                                  ...         ...
# 17777  - Bachelors Degree in the professional field (...  2015-05-26
# 17778  - Software development background;\r_- Strong ...  2015-05-26
# 17779  - University degree (MBA, MA, BA) in Accountin...  2015-05-27
# 17780  - University degree in Economics, Finance or B...  2015-05-27
# 17781  - Excellent communication skills;\r_- Knowledg...  2015-05-27
# 17782  - University degree in Finance, Economics or i...  2015-05-27
# 17783  - Bachelors degree in Computer Science, Electr...  2015-05-27
# 17784  - MA in TEFL, Linguistics or a related degree;...  2015-05-27
# 17785  - University degree in Economics or Jurisprude...  2015-05-27
# 17786  - University degree, preferably in Jurispruden...  2015-05-27
# 17787  - University degree in Economics;\r_- Knowledg...  2015-05-27
# 17788  - University degree in Economics or Jurisprude...  2015-05-27
# 17789  - University degree in History, Academy of Sci...  2015-05-29
# 17790  - Highly dynamic and positive personality, exc...  2015-05-29
# 17791  - University degree in Accounting, Economy or ...  2015-05-29
# 17792  - Higher education (preferably in Mathematics)...  2015-05-29
# 17793  - Higher education;\r_- Work experience will b...  2015-05-29
# 17794  - 1-3 years of experience in store management;...  2015-05-29
# 17795  - Higher education or Master's Degree in Econo...         NaT
# 17796  - Higher Education (Master's degree in Science...         NaT
# 17797  - B.S. in Computing Science;\r_- At least 2 ye...  2015-05-29
# 17798  - BS/ MS in Computer Science, Maths, Physics o...  2015-05-29
# 17799                                                NaN  2015-05-29
# 17800  - B.S. in Computing Science;\r_- At least 2 ye...  2015-05-29
# 17801  - Higher education;\r_- Excellent knowledge of...  2015-05-29
# 17802  - University degree from a leading institution...  2015-05-29
# 17803  - Higher education;\r_- Communication and team...  2015-05-29
# 17804  - University degree in ITC or a relevant field...  2015-05-29
# 17805  - BS in a relevant field;\r_- 2 years of work ...  2015-05-29
# 17806                                                NaN         NaT
#
#                  Deadline  Year  Month     IT
